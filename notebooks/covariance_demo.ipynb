# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
np.random.seed(0)
N=200
X = np.random.rand(N, 2)
X[:, 1] = 2 * X[:, 0] + np.random.normal(0, 0.5, N)
plt.scatter(X[:, 0], X[:, 1], c="k")
plt.xlabel("x")
plt.ylabel("y")
# Out:
# Text(0, 0.5, 'y')

# %%
np.cov(X[:, 0], X[:, 1])
# Out:
# array([[0.08008165, 0.15903956],
#        [0.15903956, 0.55885169]])
