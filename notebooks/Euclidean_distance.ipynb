# %%
import numpy as np

# %%
a = np.array([3,4,5,6,7,4])
b = np.array([3,4,1,4,7,4])

# %%
np.sqrt(np.sum((a - b)**2))
# Out:
# np.float64(4.47213595499958)

# %%
(a+b)/2
# Out:
# array([3., 4., 3., 5., 7., 4.])
