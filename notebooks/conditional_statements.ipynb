# %% [markdown]
# # Conditional Statements In Python

# %% [markdown]
# ## if
#
# if statement: This checks a condition, and if it's true, the indented code block under it will be executed.

# %%
a = 2
b = 1
if b>a:
   print("b is greater than a")
   print("inside if block")
print("outside if block")

# %%
a = 20
b = 30
if None:
    print("Inside if block")
else:
    print("Inside else block")

# %% [markdown]
# None, False, 0 are interpreted as False. All others are equivaluent to True in if-else conditions

# %%
a = "0"
if a:
    print("Inside if block")
else:
    print("Inside Else block")

# %% [markdown]
# ## elif
# elif statement: Short for "else if," this allows you to check multiple conditions. It comes after an if statement and only executes if the previous if condition was false, and the elif condition is true.

# %%
x = 8
if x > 10:
    print("x is greater than 10")
elif x == 10:
    print("x is exactly 10")
elif x < 10:
    print("x is less than 10")

# %% [markdown]
# ## else
# else statement: This captures any remaining cases that don’t match the if or elif conditions. It executes if all previous conditions are false.

# %%
x = 10
if x > 10:
    print("x is greater than 10")
elif x == 10:
    print("x is exactly 10")
else:
    print("x is less than 10")

# %% [markdown]
# ## Nested Conditional Statements
# You can also nest conditional statements for more complex checks:

# %%
digits = {0:'zero', 1:'one', 2:'two', 3:'three', 4:'four', 5:'five', 6:'six', 7:'seven', 8:'eight', 9:'nine'}
x = input("Enter your input: ").
for digit in x:
        print(digits[int(digit)], end=" ")

# %%
x = 15
if x > 10:
    print("x is greater than 10")
    if x > 20:
        print("x is also greater than 20")
    else:
        print("x is not greater than 20")

# %% [markdown]
# # Q0. Write code to print a given number is even or odd using if-else

# %% [markdown]
# # Q1. Write code print your name 'n' times

# %%
n = int(input("Enter number of times you want to print: "))
name = input("Enter your name: ")+"\n"
print(name*n)

# %% [markdown]
# ## Q1. Modify the above code to check both conditions using AND operator

# %% [markdown]
# ## Q2. Write code to check whether a given string is panlindrome or not

# %% [markdown]
# ## Q3. Write code to do check a given number is divisible by 9 if it is odd and divisible by 4 if it is even

# %% [markdown]
# ## Q4. Grade Checker: Create a program that asks the user for a score (between 0 and 100) and prints the grade based on the score:
#
# - 90 and above: "A"
# - 80 to 89: "B"
# - 70 to 79: "C"
# - 60 to 69: "D"
# - Below 60: "F"

# %% [markdown]
# #Q5. Number Sign: Write a program that takes a number as input and prints whether the number is "Positive," "Negative," or "Zero."

# %% [markdown]
# # Q6. Write code to check a given string is Panlindrome or not

# %% [markdown]
# # Q7. Write code to print a given 4 digit OTP number in text form (e.g. 0123-> Zero One Two Three)

# %%
digits = ["Zero", "One", "Two", "Three", "Four",\
          "Five", "Six", "Seven", "Eight", "Nine"]
n = input("Enter a number: ")
a,b,c,d = int(n[0]),int(n[1]),int(n[2]),int(n[3])
print(digits[a], digits[b],digits[c], digits[d])

# %% [markdown]
# Q8. Write code to print a given 4 digit OTP number in text to digit (e.g.Four Five Three Nine ->4539)

# %%
digi_dict = {"Zero":0, "One":1, "Two":2, "Three":3, "Four":4,\
          "Five":5, "Six":6, "Seven":7, "Eight":8, "Nine":9}
num_words = input("Enter number in words: ")
a,b,c,d = num_words.split(" ")
print(digi_dict[a])

# %% [markdown]
# #Q9. Write code block to print the length of characters in each sentence of a given paragraph

# %%
# Sample Input: Hello, Good morning. Welcome to DSA
# Sample Output:
# Length of sentence 1: 19
# Length of sentence 2: 14

# %%
sample_input = "Hello, Good morning. Welcome to DSA"
sentences = sample_input.split(". ")
print("Length of sentence 1: ", len(sentences[0]))
