# %%
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import Input, Flatten, Dense, Activation
from tensorflow.keras.callbacks import Callback

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
# Preprocess the data
y_train = to_categorical(y_train, num_classes=10)
y_test = to_categorical(y_test, num_classes=10)

# %%
model = Sequential()
model.add(Input(shape=(28, 28, 1)))
model.add(Flatten())
model.add(Dense(64, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(10, activation='softmax'))

# %%
class EarlyStopper(Callback):
    def __init__(self, target):
        super(EarlyStopper, self).__init__()
        self.target = target
    def on_epoch_end(self, epoch, logs={}):
        acc = logs['val_accuracy']
        if acc >= self.target:
            self.model.stop_training = True

# %%
early_stopper = EarlyStopper(0.95)

# %%
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
history = model.fit(x_train,
                    y_train,
                    validation_data=(x_test, y_test),
                    epochs=10,
                    batch_size=32,
                    callbacks=[early_stopper])
# Out:
# Epoch 1/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.7289 - loss: 4.6897 - val_accuracy: 0.8968 - val_loss: 0.4195
# Epoch 2/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8939 - loss: 0.4181 - val_accuracy: 0.9261 - val_loss: 0.2917
# Epoch 3/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.9275 - loss: 0.2754 - val_accuracy: 0.9246 - val_loss: 0.2772
# Epoch 4/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9391 - loss: 0.2183 - val_accuracy: 0.9416 - val_loss: 0.2239
# Epoch 5/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.9479 - loss: 0.1905 - val_accuracy: 0.9511 - val_loss: 0.2086
