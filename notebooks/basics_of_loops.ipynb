# %%
x = [1,2,3,4,5]
for element in x:
  print(element)

# %%
for i in range(2,11,2):
  print(i)

# %%
message = "WElcome"
for char in message:
  print(char)

# %%
message =  "WElcome"
N = len(message)
for i in range(N-1, -1, -1):
  print(message[i])

# %%
message =  "WElcome"
N = len(message)
for i in range(N):
  if i ==3:
    break
  print(message[i])

#Elco

# %%
message =  "WElcome"
N = len(message)
for i in range(N):
  if i==3:
    continue
  print(message[i])

# %%
"hello "*2

# %%
for i in range(1,20):
  if i ==13:
    continue
  print(i)

# %% [markdown]
# *****
# ****
# ***
# **
# *

# %%
for i in range(1,8,2):
  print(int((7-i)/2)*' '+i*'*')

# %%
rows = len(range(1,10))
for i in range(1,10):
  print((rows-i)*" "+i*"*")

# %%
i = 0
while i<5:
  print(i)
  i = i+1

# %% [markdown]
# #Q1. Write code to keep prompting user to enter correct gmail id (e.g. username@gmail.com)
