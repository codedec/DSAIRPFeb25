# %% [markdown]
# ## Basics Code Block

# %%
print("hello")
# Out:
# hello

# %% [markdown]
# ## Headings and Sub-headings

# %% [markdown]
# ## Images

# %% [markdown]
# ![Landscape](https://media.istockphoto.com/id/485371557/photo/twilight-at-spirit-island.jpg?s=612x612&w=0&k=20&c=FSGliJ4EKFP70Yjpzso0HfRR4WwflC6GKfl4F3Hj7fk=)

# %% [markdown]
# ## Hyperlink

# %% [markdown]
# [Google.com](http://www.google.com)

# %% [markdown]
# ## Equations

# %% [markdown]
# $y = mx+c$
